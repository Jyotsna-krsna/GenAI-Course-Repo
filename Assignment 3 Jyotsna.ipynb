# %% [markdown]
# # **Assignment 3**

# %%
#A function that  that copies the contents of a file named source.txt to a new file named destination.txt.
def copy_file():
  with open('output.txt','w') as f:
    f.write('This is first line\n')
    f.write('This is second line\n')
    f.write('This is third line\n')

#call function write_file
write_file()

#read and print file
with open('output.txt') as f:
  print(f.read())
# Out:
# This is first line
# This is second line
# This is third line
